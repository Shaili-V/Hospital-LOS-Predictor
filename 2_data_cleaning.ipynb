# %% [markdown]
# # Data Cleaning
# This file contains code to clean the "hospital.csv" datasest and create a new dataset.
#
# After researching each column's meaning, looking at null values, considering what data is decided after the length of stay, and discussing the findings, we chose 12 columns to keep from the original 33. These columns includes 1 target column, "Length of Stay", and 11 feature columns--"Age Group", "Gender", "Type of Admission", "CCSR Diagnosis Description", "CCSR Procedure Description", "APR DRG Description", "APR Severity of Illness Description", "APR Risk of Mortality", "APR Medical Surgical Description", "Emergency Department Indicator", "APR MDC Description.
#
# The cleaning steps include tidying and renaming the columns (lowercase with underscores for spaces) as well as dropping null values and creating a new dataset named "hospital_cleaned.csv"
#
# The main purpose of this file is to clean the dataset based on the data deemed relevant for predicting length of stay and to prepare the data for models.

# %%
# Load libraries
import pandas as pd

# %%
# Load in the dataset as a pandas dataframe
data = pd.read_csv('hospital.csv')
# Out:
# /var/folders/cn/yq8hnccx3n309s8g15blkpv80000gp/T/ipykernel_25318/4272719286.py:2: DtypeWarning: Columns (10,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('hospital.csv')

# %% [markdown]
# ## Picking Columns

# %%
# Create new dataframe with only specific columns chosen based on  analysis of the data
df = data[["Length of Stay", "Age Group", "Gender", "Type of Admission", "CCSR Diagnosis Description", "CCSR Procedure Description", "APR DRG Description", "APR Severity of Illness Description", "APR Risk of Mortality", "APR Medical Surgical Description", "Emergency Department Indicator", "APR MDC Description"]]
print(df.head())
# Out:
#   Length of Stay    Age Group Gender Type of Admission  \
# 0             27  70 or Older      M         Emergency
# 1              4     50 to 69      F         Emergency
# 2              2     18 to 29      F         Emergency
# 3              5  70 or Older      M         Emergency
# 4              3     50 to 69      F         Emergency
#
#               CCSR Diagnosis Description  \
# 0    CORONAVIRUS DISEASE 2019 (COVID-19)
# 1                     MULTIPLE SCLEROSIS
# 2                     PREVIOUS C-SECTION
# 3               URINARY TRACT INFECTIONS
# 4  PARALYSIS (OTHER THAN CEREBRAL PALSY)
#
#                           CCSR Procedure Description  \
# 0                               ISOLATION PROCEDURES
# 1                                                NaN
# 2                                   CESAREAN SECTION
# 3  ADMINISTRATION OF NUTRITIONAL AND ELECTROLYTIC...
# 4                                    LUMBAR PUNCTURE
#
#                                  APR DRG Description  \
# 0     MAJOR RESPIRATORY INFECTIONS AND INFLAMMATIONS
# 1  MULTIPLE SCLEROSIS, OTHER DEMYELINATING DISEAS...
# 2             CESAREAN SECTION WITHOUT STERILIZATION
# 3                KIDNEY AND URINARY TRACT INFECTIONS
# 4                  OTHER DISORDERS OF NERVOUS SYSTEM
#
#   APR Severity of Illness Description APR Risk of Mortality  \
# 0                               Major               Extreme
# 1                            Moderate                 Minor
# 2                               Minor                 Minor
# 3                               Major                 Major
# 4                            Moderate                 Minor
#
#   APR Medical Surgical Description Emergency Department Indicator  \
# 0                          Medical                              Y
# 1                          Medical                              Y
# 2                         Surgical                              N
# 3                          Medical                              Y
# 4                          Medical                              Y
#
#                                  APR MDC Description
# 0   DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 1       DISEASES AND DISORDERS OF THE NERVOUS SYSTEM
# 2           PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 3  DISEASES AND DISORDERS OF THE KIDNEY AND URINA...
# 4       DISEASES AND DISORDERS OF THE NERVOUS SYSTEM

# %% [markdown]
# ## Tidying the Columns

# %%
# Rename, strip, lowercase, remove symbols clean the columns
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(' ', '_')
      .str.replace(r'[^0-9a-z_]', '', regex=True)
)

# %% [markdown]
# ## Drop Nulls from the Length of Stay Column (Target)

# %%
# Cleaning up length_of_stay
initial_rows = len(df)
df = df.dropna(subset=['length_of_stay'])
dropped_nulls = initial_rows - len(df)
print(f"Dropped {dropped_nulls} rows with null length_of_stay")

initial_rows = len(df)
df['length_of_stay'] = pd.to_numeric(df['length_of_stay'], errors='coerce')
df = df.dropna(subset=['length_of_stay'])
dropped_non_numeric = initial_rows - len(df)
print(f"Dropped {dropped_non_numeric} rows during conversion to numeric")
# Out:
# Dropped 0 rows with null length_of_stay
# Dropped 1561 rows during conversion to numeric

# %%
# Check progress of the cleaning steps so far
print(df.head())
print(df.columns.tolist())
# Out:
#    length_of_stay    age_group gender type_of_admission  \
# 0            27.0  70 or Older      M         Emergency
# 1             4.0     50 to 69      F         Emergency
# 2             2.0     18 to 29      F         Emergency
# 3             5.0  70 or Older      M         Emergency
# 4             3.0     50 to 69      F         Emergency
#
#               ccsr_diagnosis_description  \
# 0    CORONAVIRUS DISEASE 2019 (COVID-19)
# 1                     MULTIPLE SCLEROSIS
# 2                     PREVIOUS C-SECTION
# 3               URINARY TRACT INFECTIONS
# 4  PARALYSIS (OTHER THAN CEREBRAL PALSY)
#
#                           ccsr_procedure_description  \
# 0                               ISOLATION PROCEDURES
# 1                                                NaN
# 2                                   CESAREAN SECTION
# 3  ADMINISTRATION OF NUTRITIONAL AND ELECTROLYTIC...
# 4                                    LUMBAR PUNCTURE
#
#                                  apr_drg_description  \
# 0     MAJOR RESPIRATORY INFECTIONS AND INFLAMMATIONS
# 1  MULTIPLE SCLEROSIS, OTHER DEMYELINATING DISEAS...
# 2             CESAREAN SECTION WITHOUT STERILIZATION
# 3                KIDNEY AND URINARY TRACT INFECTIONS
# 4                  OTHER DISORDERS OF NERVOUS SYSTEM
#
#   apr_severity_of_illness_description apr_risk_of_mortality  \
# 0                               Major               Extreme
# 1                            Moderate                 Minor
# 2                               Minor                 Minor
# 3                               Major                 Major
# 4                            Moderate                 Minor
#
#   apr_medical_surgical_description emergency_department_indicator  \
# 0                          Medical                              Y
# 1                          Medical                              Y
# 2                         Surgical                              N
# 3                          Medical                              Y
# 4                          Medical                              Y
#
#                                  apr_mdc_description
# 0   DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM
# 1       DISEASES AND DISORDERS OF THE NERVOUS SYSTEM
# 2           PREGNANCY, CHILDBIRTH AND THE PUERPERIUM
# 3  DISEASES AND DISORDERS OF THE KIDNEY AND URINA...
# 4       DISEASES AND DISORDERS OF THE NERVOUS SYSTEM
# ['length_of_stay', 'age_group', 'gender', 'type_of_admission', 'ccsr_diagnosis_description', 'ccsr_procedure_description', 'apr_drg_description', 'apr_severity_of_illness_description', 'apr_risk_of_mortality', 'apr_medical_surgical_description', 'emergency_department_indicator', 'apr_mdc_description']

# %% [markdown]
# ## Unique counts

# %%
# Get counts of unique items in each column
columns_list = df.columns.tolist()
# Check unique values in certain columns
for column in columns_list:
    unique_values = df[column].unique()
    print(f"{column} : {unique_values} ")

print("Unique value counts per column:")
print(df.nunique())
# Out:
# length_of_stay : [ 27.   4.   2.   5.   3.   6.   1.  21.   7.   9.  14.  19.  24.  16.
#    8.  11.  13.  10.  28.  37.  22.  20.  33.  30.  15.  12.  46.  18.
#   29.  17.  43.  32.  25.  34.  53.  38.  23.  83. 103.  35.  36.  42.
#   44.  57.  45.  40.  84.  39.  31.  77.  26.  71.  81.  54.  63.  41.
#   51.  58.  99.  59.  97. 111.  49.  47.  56.  52.  80.  86.  74. 102.
#   48.  64.  68.  78.  55.  50.  72.  62.  70. 108.  66.  88.  61.  75.
#   73. 117.  67. 114. 116.  95. 113.  76.  60.  90. 106. 115.  65. 118.
#   96.  69.  91.  93.  98.  94.  87.  82.  85. 100. 119. 104.  92. 107.
#   79. 101.  89. 110. 109. 105. 112.]
# age_group : ['70 or Older' '50 to 69' '18 to 29' '0 to 17' '30 to 49']
# gender : ['M' 'F' 'U']
# type_of_admission : ['Emergency' 'Newborn' 'Elective' 'Urgent' 'Trauma' 'Not Available']
# ccsr_diagnosis_description : ['CORONAVIRUS DISEASE 2019 (COVID-19)' 'MULTIPLE SCLEROSIS'
#  'PREVIOUS C-SECTION' 'URINARY TRACT INFECTIONS'
#  'PARALYSIS (OTHER THAN CEREBRAL PALSY)'
#  'COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE, INJURY, INITIAL ENCOUNTER'
#  'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, INITIAL ENCOUNTER' 'LIVEBORN'
#  'NONINFECTIOUS GASTROENTERITIS' 'ASTHMA'
#  'DIABETES MELLITUS WITH COMPLICATION' 'SICKLE CELL TRAIT/ANEMIA'
#  'CHRONIC OBSTRUCTIVE PULMONARY DISEASE AND BRONCHIECTASIS'
#  'OTHER SPECIFIED DISEASES OF VEINS AND LYMPHATICS'
#  'STRESS FRACTURE, INITIAL ENCOUNTER'
#  'ENCOUNTER FOR ANTINEOPLASTIC THERAPIES' 'BENIGN NEOPLASMS'
#  'NERVE AND NERVE ROOT DISORDERS'
#  'COMPLICATION OF TRANSPLANTED ORGANS OR TISSUE, INITIAL ENCOUNTER'
#  'FLUID AND ELECTROLYTE DISORDERS' 'INTESTINAL OBSTRUCTION AND ILEUS'
#  'EPILEPSY; CONVULSIONS' 'MALE REPRODUCTIVE SYSTEM CANCERS - PROSTATE'
#  'SCHIZOPHRENIA SPECTRUM AND OTHER PSYCHOTIC DISORDERS'
#  'CORONARY ATHEROSCLEROSIS AND OTHER HEART DISEASE'
#  'ALCOHOL-RELATED DISORDERS'
#  'HYPERTENSION AND HYPERTENSIVE-RELATED CONDITIONS COMPLICATING PREGNANCY; CHILDBIRTH; AND THE PUERPERIUM'
#  'CEREBRAL INFARCTION'
#  'OTHER SPECIFIED AND UNSPECIFIED GASTROINTESTINAL DISORDERS'
#  'FRACTURE OF TORSO, INITIAL ENCOUNTER'
#  'COMPLICATIONS SPECIFIED DURING CHILDBIRTH' 'SEPTICEMIA' 'HEART FAILURE'
#  'GANGRENE' 'NEUROCOGNITIVE DISORDERS' 'ACUTE MYOCARDIAL INFARCTION'
#  'ACUTE PULMONARY EMBOLISM' 'HEADACHE; INCLUDING MIGRAINE' 'OBESITY'
#  'NERVOUS SYSTEM PAIN AND PAIN SYNDROMES' 'ASPIRATION PNEUMONITIS'
#  'SPONDYLOPATHIES/SPONDYLOARTHROPATHY (INCLUDING INFECTIVE)'
#  'DISLOCATIONS, INITIAL ENCOUNTER' 'MULTIPLE MYELOMA'
#  'BILIARY TRACT DISEASE' 'CHRONIC KIDNEY DISEASE'
#  'POISONING BY DRUGS, INITIAL ENCOUNTER' 'SECONDARY MALIGNANCIES'
#  'POSTPROCEDURAL OR POSTOPERATIVE DIGESTIVE SYSTEM COMPLICATION'
#  'DIVERTICULOSIS AND DIVERTICULITIS'
#  'MALPOSITION, DISPROPORTION OR OTHER LABOR COMPLICATIONS'
#  'APPENDICITIS AND OTHER APPENDICEAL CONDITIONS'
#  'DIABETES OR ABNORMAL GLUCOSE TOLERANCE COMPLICATING PREGNANCY; CHILDBIRTH; OR THE PUERPERIUM'
#  'OTHER SPECIFIED AND UNSPECIFIED MOOD DISORDERS'
#  'MATERNAL CARE RELATED TO FETAL CONDITIONS'
#  'OTHER SPECIFIED SUBSTANCE-RELATED DISORDERS'
#  'OPEN WOUNDS OF HEAD AND NECK, INITIAL ENCOUNTER'
#  'PNEUMONIA (EXCEPT THAT CAUSED BY TUBERCULOSIS)'
#  'CIRCULATORY SIGNS AND SYMPTOMS' 'NAUSEA AND VOMITING' 'MENINGITIS'
#  'PERITONITIS AND INTRA-ABDOMINAL ABSCESS' 'STIMULANT-RELATED DISORDERS'
#  'SYNCOPE' 'GASTRODUODENAL ULCER'
#  'FRACTURE OF THE UPPER LIMB, INITIAL ENCOUNTER' 'CARDIAC DYSRHYTHMIAS'
#  'OPEN WOUNDS TO LIMBS, INITIAL ENCOUNTER' 'ABDOMINAL HERNIA'
#  'TRANSIENT CEREBRAL ISCHEMIA'
#  'MOLAR PREGNANCY AND OTHER ABNORMAL PRODUCTS OF CONCEPTION'
#  'BENIGN OVARIAN CYST' 'GASTRITIS AND DUODENITIS' 'ALLERGIC REACTIONS'
#  'AMPUTATION OF A LIMB, INITIAL ENCOUNTER'
#  'ACUTE AND UNSPECIFIED RENAL FAILURE'
#  'SKIN AND SUBCUTANEOUS TISSUE INFECTIONS' 'DEPRESSIVE DISORDERS'
#  'RESPIRATORY FAILURE; INSUFFICIENCY; ARREST'
#  'BIPOLAR AND RELATED DISORDERS' 'TRAUMA- AND STRESSOR-RELATED DISORDERS'
#  'MATERNAL CARE RELATED TO DISORDERS OF THE PLACENTA AND PLACENTAL IMPLANTATION'
#  'NEURO-OPHTHALMOLOGY' 'HEMORRHOIDS' 'NONINFECTIOUS HEPATITIS'
#  'PROLONGED PREGNANCY'
#  'ECTOPIC PREGNANCY AND COMPLICATIONS OF ECTOPIC PREGNANCY'
#  'EARLY, FIRST OR UNSPECIFIED TRIMESTER HEMORRHAGE'
#  'OTHER AFTERCARE ENCOUNTER' 'ACUTE BRONCHITIS' 'PERINATAL INFECTIONS'
#  'POLYHYDRAMNIOS AND OTHER PROBLEMS OF AMNIOTIC CAVITY'
#  'MALAISE AND FATIGUE' 'SEQUELA OF HEMORRHAGIC CEREBROVASCULAR DISEASE'
#  'EARLY OR THREATENED LABOR' 'OSTEOARTHRITIS'
#  'UNCOMPLICATED PREGNANCY, DELIVERY OR PUERPERIUM'
#  'OCCLUSION OR STENOSIS OF PRECEREBRAL OR CEREBRAL ARTERIES WITHOUT INFARCTION'
#  'RESPIRATORY CANCERS' 'MULTIPLE GESTATION' 'PNEUMOTHORAX'
#  'IMMUNITY DISORDERS' 'OTHER SPECIFIED NERVOUS SYSTEM DISORDERS'
#  'PANCREATIC DISORDERS (EXCLUDING DIABETES)' 'ESOPHAGEAL DISORDERS'
#  'OTHER SPECIFIED AND UNSPECIFIED DISEASES OF KIDNEY AND URETERS'
#  'ABDOMINAL PAIN AND OTHER DIGESTIVE/ABDOMEN SIGNS AND SYMPTOMS'
#  'MYELODYSPLASTIC SYNDROME (MDS)'
#  'OTHER AND ILL-DEFINED CEREBROVASCULAR DISEASE'
#  'CARDIAC ARREST AND VENTRICULAR FIBRILLATION'
#  'SPONTANEOUS ABORTION AND COMPLICATIONS OF SPONTANEOUS ABORTION'
#  'GASTROINTESTINAL CANCERS - STOMACH'
#  'INFLAMMATORY CONDITIONS OF MALE GENITAL ORGANS' 'SLEEP WAKE DISORDERS'
#  'OTHER SPECIFIED AND UNSPECIFIED DISEASES OF BLADDER AND URETHRA'
#  'OTHER SPECIFIED AND UNSPECIFIED SKIN DISORDERS'
#  'PERIPHERAL AND VISCERAL VASCULAR DISEASE' 'ESSENTIAL HYPERTENSION'
#  'OSTEOMYELITIS' 'OTHER SPECIFIED COMPLICATIONS IN PREGNANCY'
#  'GASTROINTESTINAL HEMORRHAGE' 'PERSONALITY DISORDERS'
#  'INTERNAL ORGAN INJURY, INITIAL ENCOUNTER' 'MESOTHELIOMA'
#  'PERICARDITIS AND PERICARDIAL DISEASE'
#  'HYPERTENSION WITH COMPLICATIONS AND SECONDARY HYPERTENSION'
#  'FRACTURE OF THE NECK OF THE FEMUR (HIP), INITIAL ENCOUNTER'
#  'POSTTHROMBOTIC SYNDROME AND VENOUS INSUFFICIENCY/HYPERTENSION'
#  'SEQUELA OF CEREBRAL INFARCTION AND OTHER CEREBROVASCULAR DISEASE'
#  'ANXIETY AND FEAR-RELATED DISORDERS'
#  'LEUKEMIA - ACUTE MYELOID LEUKEMIA (AML)'
#  'URINARY SYSTEM CANCERS - BLADDER'
#  'GENERAL SENSATION/PERCEPTION SIGNS AND SYMPTOMS' 'ARTERIAL DISSECTIONS'
#  'FRACTURE OF THE LOWER LIMB (EXCEPT HIP), INITIAL ENCOUNTER'
#  'ACUTE PHLEBITIS; THROMBOPHLEBITIS AND THROMBOEMBOLISM'
#  'ABNORMAL FINDINGS WITHOUT DIAGNOSIS'
#  'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, SUBSEQUENT ENCOUNTER'
#  'COMPLICATION OF INTERNAL ORTHOPEDIC DEVICE OR IMPLANT, INITIAL ENCOUNTER'
#  'COMPLICATION OF GENITOURINARY DEVICE, IMPLANT OR GRAFT, INITIAL ENCOUNTER'
#  'HYPOTENSION' 'SUICIDAL IDEATION/ATTEMPT/INTENTIONAL SELF-HARM'
#  'DRUG INDUCED OR TOXIC RELATED CONDITION' 'OPIOID-RELATED DISORDERS'
#  'OTHER SPECIFIED AND UNSPECIFIED LIVER DISEASE' 'NONSPECIFIC CHEST PAIN'
#  'INFECTIVE ARTHRITIS' 'SARCOMA'
#  'OTHER SPECIFIED AND UNSPECIFIED PERINATAL CONDITIONS'
#  'CANNABIS-RELATED DISORDERS' 'NEURODEVELOPMENTAL DISORDERS'
#  'CHRONIC RHEUMATIC HEART DISEASE' 'HEPATITIS'
#  'HEMOLYTIC JAUNDICE AND PERINATAL JAUNDICE' 'MUSCLE DISORDERS'
#  'DYSPHAGIA' 'CONDUCTION DISORDERS' 'TOXIC EFFECTS, INITIAL ENCOUNTER'
#  'PITUITARY DISORDERS' 'AORTIC; PERIPHERAL; AND VISCERAL ARTERY ANEURYSMS'
#  'INTESTINAL INFECTION'
#  'EFFECT OF FOREIGN BODY ENTERING OPENING, INITIAL ENCOUNTER'
#  'BREAST CANCER - ALL OTHER TYPES'
#  'INFLAMMATORY DISEASES OF FEMALE PELVIC ORGANS'
#  'FRACTURE OF HEAD AND NECK, INITIAL ENCOUNTER' 'ERECTILE DYSFUNCTION'
#  'SUPERFICIAL INJURY; CONTUSION, INITIAL ENCOUNTER'
#  'POSTPROCEDURAL OR POSTOPERATIVE RESPIRATORY SYSTEM COMPLICATION'
#  'TENDON AND SYNOVIAL DISORDERS'
#  'SYSTEMIC LUPUS ERYTHEMATOSUS AND CONNECTIVE TISSUE DISORDERS'
#  'NERVOUS SYSTEM CONGENITAL ANOMALIES'
#  'AORTIC AND PERIPHERAL ARTERIAL EMBOLISM OR THROMBOSIS'
#  'HYPERPLASIA OF PROSTATE' 'OTHER UNSPECIFIED INJURY'
#  'NEPHRITIS; NEPHROSIS; RENAL SCLEROSIS'
#  'OTHER SPECIFIED UPPER RESPIRATORY INFECTIONS'
#  'NEOPLASM-RELATED ENCOUNTERS' 'CALCULUS OF URINARY TRACT'
#  'GENITOURINARY CONGENITAL ANOMALIES' 'NONMALIGNANT BREAST CONDITIONS'
#  'OTHER SPECIFIED AND UNSPECIFIED LOWER RESPIRATORY DISEASE'
#  'MUSCULOSKELETAL PAIN, NOT LOW BACK PAIN'
#  'NERVOUS SYSTEM SIGNS AND SYMPTOMS' 'ACUTE AND CHRONIC TONSILLITIS'
#  'OTHER GENERAL SIGNS AND SYMPTOMS'
#  'OTHER SPECIFIED HEREDITARY AND DEGENERATIVE NERVOUS SYSTEM CONDITIONS'
#  'ANAL AND RECTAL CONDITIONS' 'POLYNEUROPATHIES'
#  'RESPIRATORY SIGNS AND SYMPTOMS' 'COAGULATION AND HEMORRHAGIC DISORDERS'
#  'DISEASES OF INNER EAR AND RELATED CONDITIONS' 'HEPATIC FAILURE'
#  'NON-PRESSURE ULCER OF SKIN' 'GASTROINTESTINAL CANCERS - COLORECTAL'
#  'COMPLICATIONS SPECIFIED DURING THE PUERPERIUM' 'CLEFT LIP OR PALATE'
#  'ACQUIRED DEFORMITIES (EXCLUDING FOOT)'
#  'ACUTE HEMORRHAGIC CEREBROVASCULAR DISEASE'
#  'OTHER SPECIFIED INFLAMMATORY CONDITION OF SKIN'
#  'MUSCULOSKELETAL CONGENITAL CONDITIONS' 'INJURY, SEQUELA'
#  'NONRHEUMATIC AND UNSPECIFIED VALVE DISORDERS'
#  'SCOLIOSIS AND OTHER POSTURAL DORSOPATHIC DEFORMITIES'
#  'OTHER SPECIFIED AND UNSPECIFIED UPPER RESPIRATORY DISEASE'
#  'PARKINSON`S DISEASE' 'DISORDERS OF JAW'
#  'OB-RELATED TRAUMA TO PERINEUM AND VULVA'
#  'COMA; STUPOR; AND BRAIN DAMAGE'
#  'MATERNAL CARE FOR ABNORMALITY OF PELVIC ORGANS'
#  'ACUTE POSTHEMORRHAGIC ANEMIA' 'MALNUTRITION'
#  'OPEN WOUNDS OF TRUNK, INITIAL ENCOUNTER'
#  'FRACTURE OF LOWER LIMB (EXCEPT HIP), SUBSEQUENT ENCOUNTER'
#  'FRACTURE OF TORSO, SUBSEQUENT ENCOUNTER'
#  'OTHER SPECIFIED AND UNSPECIFIED NUTRITIONAL AND METABOLIC DISORDERS'
#  'DISORDERS OF TEETH AND GINGIVA' 'HALLUCINOGEN-RELATED DISORDERS'
#  'ENDOMETRIOSIS' 'APLASTIC ANEMIA' 'ENDOCRINE SYSTEM CANCERS - PANCREAS'
#  'GASTROINTESTINAL CANCERS - ALL OTHER TYPES'
#  'PROLAPSE OF FEMALE GENITAL ORGANS'
#  'PLEURISY, PLEURAL EFFUSION AND PULMONARY COLLAPSE'
#  'EFFECT OF OTHER EXTERNAL CAUSES, INITIAL ENCOUNTER'
#  'BURN AND CORROSION, INITIAL ENCOUNTER'
#  'INJURY TO BLOOD VESSELS, INITIAL ENCOUNTER'
#  'FRACTURE OF THE SPINE AND BACK, INITIAL ENCOUNTER'
#  'POSTPROCEDURAL OR POSTOPERATIVE ENDOCRINE OR METABOLIC COMPLICATION'
#  'COMPLICATION OF CARDIOVASCULAR DEVICE, IMPLANT OR GRAFT, INITIAL ENCOUNTER'
#  'MYOCARDITIS AND CARDIOMYOPATHY'
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - CERVIX' 'MALTREATMENT/ABUSE'
#  'POSTPROCEDURAL OR POSTOPERATIVE CIRCULATORY SYSTEM COMPLICATION'
#  'NUTRITIONAL ANEMIA'
#  'OTHER SPECIFIED AND UNSPECIFIED ENDOCRINE DISORDERS'
#  'GASTROINTESTINAL CANCERS - LIVER'
#  'MISCELLANEOUS MENTAL AND BEHAVIORAL DISORDERS/CONDITIONS'
#  'RETINAL AND VITREOUS CONDITIONS'
#  'INDUCED ABORTION AND COMPLICATIONS OF TERMINATION OF PREGNANCY'
#  'ENCOUNTER FOR PROPHYLACTIC OR OTHER PROCEDURES'
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - ENDOMETRIUM'
#  'PULMONARY HEART DISEASE' 'OTHER SPECIFIED CONNECTIVE TISSUE DISEASE'
#  'INTERNAL ORGAN INJURY, SUBSEQUENT ENCOUNTER'
#  'GASTROINTESTINAL CANCERS - PERITONEUM'
#  'FRACTURE OF THE NECK OF THE FEMUR (HIP), SUBSEQUENT ENCOUNTER'
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - UTERUS'
#  'RHEUMATOID ARTHRITIS AND RELATED DISEASE' 'NUTRITIONAL DEFICIENCIES'
#  'POSTPROCEDURAL OR POSTOPERATIVE GENITOURINARY SYSTEM COMPLICATION'
#  'REGIONAL ENTERITIS AND ULCERATIVE COLITIS'
#  'NEONATAL DIGESTIVE AND FEEDING DISORDERS'
#  'PATHOLOGICAL FRACTURE, SUBSEQUENT ENCOUNTER' 'THYROID DISORDERS'
#  'CONTACT DERMATITIS'
#  'OTHER SPECIFIED AND UNSPECIFIED DISORDERS OF STOMACH AND DUODENUM'
#  'LEUKEMIA - ALL OTHER TYPES' 'VARICOSE VEINS OF LOWER EXTREMITY'
#  'NON-HODGKIN LYMPHOMA' 'BONE CANCER'
#  'FRACTURE OF THE SPINE AND BACK, SUBSEQUENT ENCOUNTER'
#  'DISRUPTIVE, IMPULSE-CONTROL AND CONDUCT DISORDERS'
#  'OTHER SPECIFIED FEMALE GENITAL DISORDERS'
#  'DISEASES OF WHITE BLOOD CELLS' 'VIRAL INFECTION'
#  'ENDOCARDITIS AND ENDOCARDIAL DISEASE'
#  'BREAST CANCER - DUCTAL CARCINOMA IN SITU (DCIS)'
#  'PRESSURE ULCER OF SKIN' 'SPRAINS AND STRAINS, INITIAL ENCOUNTER'
#  'MALIGNANT NEUROENDOCRINE TUMORS' 'GOUT' 'FUNGAL INFECTIONS'
#  'BLINDNESS AND VISION DEFECTS' 'TOXIC EFFECTS, SUBSEQUENT ENCOUNTER'
#  'OTHER SPECIFIED BONE DISEASE AND MUSCULOSKELETAL DEFORMITIES'
#  'ENDOCRINE SYSTEM CANCERS - THYROID' 'SKIN CANCERS - MELANOMA'
#  'NEONATAL CEREBRAL DISORDERS'
#  'CONDITIONS DUE TO NEOPLASM OR THE TREATMENT OF NEOPLASM'
#  'BACTERIAL INFECTIONS'
#  'POSTPROCEDURAL OR POSTOPERATIVE MUSCULOSKELETAL SYSTEM COMPLICATION'
#  'FEEDING AND EATING DISORDERS' 'GASTROINTESTINAL CANCERS - ANUS'
#  'CONGENITAL MALFORMATIONS OF EYE, EAR, FACE, NECK'
#  'OTHER SPECIFIED JOINT DISORDERS' 'OSTEOPOROSIS'
#  'ACQUIRED FOOT DEFORMITIES' 'ASEPTIC NECROSIS AND OSTEONECROSIS'
#  'INJURY TO NERVES, MUSCLES AND TENDONS, INITIAL ENCOUNTER'
#  'PATHOLOGICAL FRACTURE, INITIAL ENCOUNTER'
#  'POSTPROCEDURAL OR POSTOPERATIVE NERVOUS SYSTEM COMPLICATION'
#  'URINARY SYSTEM CANCERS - KIDNEY'
#  'POSTPROCEDURAL OR POSTOPERATIVE SKIN COMPLICATION'
#  'HEAD AND NECK CANCERS - SALIVARY GLAND' 'MENOPAUSAL DISORDERS'
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - OVARY'
#  'OTHER SPECIFIED AND UNSPECIFIED CIRCULATORY DISEASE' 'HIV INFECTION'
#  'LOW BACK PAIN' 'OTHER AND ILL-DEFINED HEART DISEASE' 'HEMOLYTIC ANEMIA'
#  'SEDATIVE-RELATED DISORDERS'
#  'PARASITIC, OTHER SPECIFIED AND UNSPECIFIED INFECTIONS'
#  'GASTROINTESTINAL CANCERS - BILE DUCT'
#  'URINARY SYSTEM CANCERS - URETER AND RENAL PELVIS'
#  'OTHER SPECIFIED AND UNSPECIFIED CONGENITAL ANOMALIES'
#  'MATERNAL INTRAUTERINE INFECTION' 'MEDIASTINAL DISORDERS' 'MYOPATHIES'
#  'MEDICAL EXAMINATION/EVALUATION' 'OTHER SPECIFIED STATUS'
#  'CARDIAC AND CIRCULATORY CONGENITAL ANOMALIES'
#  'DISEASES OF MOUTH; EXCLUDING DENTAL'
#  'RESPIRATORY CONGENITAL MALFORMATIONS' 'NERVOUS SYSTEM CANCERS - BRAIN'
#  'DIGESTIVE CONGENITAL ANOMALIES'
#  'BURNS AND CORROSION, SUBSEQUENT ENCOUNTER' 'HEMATURIA' 'ENCEPHALITIS'
#  'RESPIRATORY DISTRESS SYNDROME' 'HODGKIN LYMPHOMA'
#  'OTHER SPECIFIED MALE GENITAL DISORDERS'
#  'SPINAL CORD INJURY (SCI), INITIAL ENCOUNTER'
#  'FRACTURE OF HEAD AND NECK, SUBSEQUENT ENCOUNTER'
#  'HEAD AND NECK CANCERS - THROAT'
#  'OTHER SPECIFIED AND UNSPECIFIED HEMATOLOGIC CONDITIONS'
#  'MENSTRUAL DISORDERS' 'MENTAL AND SUBSTANCE USE DISORDERS IN REMISSION'
#  'FEVER' 'CRUSHING INJURY, INITIAL ENCOUNTER'
#  'HEAD AND NECK CANCERS - LARYNGEAL'
#  'HEAD AND NECK CANCERS - LIP AND ORAL CAVITY'
#  'OTHER SPECIFIED EYE DISORDERS'
#  'SEXUALLY TRANSMITTED INFECTIONS (EXCLUDING HIV AND HEPATITIS)'
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - VAGINA'
#  'SKIN CANCERS - SQUAMOUS CELL CARCINOMA'
#  'GASTROINTESTINAL CANCERS - ESOPHAGUS' 'OTHER SPECIFIED INJURY'
#  'GASTROINTESTINAL CANCERS - SMALL INTESTINE'
#  'GASTROINTESTINAL CANCERS - GALLBLADDER'
#  'ENCOUNTER FOR OBSERVATION AND EXAMINATION FOR CONDITIONS RULED OUT (EXCLUDES INFECTIOUS DISEASE, NEOPLASM, MENTAL DISORDERS)'
#  'LEUKEMIA - ACUTE LYMPHOBLASTIC LEUKEMIA (ALL)'
#  'NEOPLASMS OF UNSPECIFIED NATURE OR UNCERTAIN BEHAVIOR'
#  'OTHER SPECIFIED AND UNSPECIFIED DISORDERS OF THE EAR'
#  'FOODBORNE INTOXICATIONS'
#  'DISEASES OF MIDDLE EAR AND MASTOID (EXCEPT OTITIS MEDIA)'
#  'HEMORRHAGIC AND HEMATOLOGIC DISORDERS OF NEWBORN'
#  'SKIN/SUBCUTANEOUS SIGNS AND SYMPTOMS'
#  'OBSTETRIC HISTORY AFFECTING CARE IN PREGNANCY'
#  'CORNEA AND EXTERNAL DISEASE' 'RESPIRATORY PERINATAL CONDITION'
#  'OTHER SPECIFIED CNS INFECTION AND POLIOMYELITIS'
#  'OCULOFACIAL PLASTICS AND ORBITAL CONDITIONS' 'CANCER OF OTHER SITES'
#  'OBSESSIVE-COMPULSIVE AND RELATED DISORDERS'
#  'FRACTURE OF THE UPPER LIMB, SUBSEQUENT ENCOUNTER'
#  'DISORDERS OF LIPID METABOLISM' 'UVEITIS AND OCULAR INFLAMMATION'
#  'ATYPICAL FRACTURE, INITIAL ENCOUNTER' 'SINUSITIS'
#  'SPINAL CORD INJURY (SCI), SUBSEQUENT ENCOUNTER'
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - FALLOPIAN TUBE'
#  'INJURY TO NERVES, MUSCLES AND TENDONS, SUBSEQUENT ENCOUNTER'
#  'SYMPTOMS OF MENTAL AND SUBSTANCE USE CONDITIONS'
#  'MALE REPRODUCTIVE SYSTEM CANCERS - PENIS'
#  'HEMORRHAGE AFTER FIRST TRIMESTER'
#  'COMPLICATIONS OF ACUTE MYOCARDIAL INFARCTION'
#  'MALE REPRODUCTIVE SYSTEM CANCERS - TESTIS' 'SOMATIC DISORDERS'
#  'TRAUMATIC ARTHROPATHY' 'HEAD AND NECK CANCERS - TONSILS'
#  'LEUKEMIA - CHRONIC MYELOID LEUKEMIA (CML)' 'CNS ABSCESS'
#  'LEUKEMIA - CHRONIC LYMPHOCYTIC LEUKEMIA (CLL)'
#  'LUNG DISEASE DUE TO EXTERNAL AGENTS' 'CEREBRAL PALSY'
#  'CRUSHING INJURY, SUBSEQUENT ENCOUNTER'
#  'OPEN WOUNDS TO LIMBS, SUBSEQUENT ENCOUNTER'
#  'SKIN CANCERS - BASAL CELL CARCINOMA'
#  'MALE REPRODUCTIVE SYSTEM CANCERS - ALL OTHER TYPES'
#  'GENITOURINARY SIGNS AND SYMPTOMS' 'INFLUENZA' nan
#  'SKIN CANCERS - ALL OTHER TYPES'
#  'IMPLANT, DEVICE OR GRAFT RELATED ENCOUNTER' 'SHOCK'
#  'CRYSTAL ARTHROPATHIES (EXCLUDING GOUT)'
#  'URINARY SYSTEM CANCERS - ALL OTHER TYPES'
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - VULVA'
#  'MALIGNANT NEOPLASM, UNSPECIFIED'
#  'HEAD AND NECK CANCERS - ALL OTHER TYPES' 'CYSTIC FIBROSIS'
#  'PATHOLOGICAL, STRESS AND ATYPICAL FRACTURES, SEQUELA' 'GLAUCOMA'
#  'IMMUNE-MEDIATED/REACTIVE ARTHROPATHIES'
#  'GASTROINTESTINAL AND BILIARY PERFORATION'
#  'HEAD AND NECK CANCERS - HYPOPHARYNGEAL' 'CARDIAC CANCERS'
#  'SEQUELA OF SPECIFIED NERVOUS SYSTEM CONDITIONS' 'COMPLICATION, SEQUELA'
#  'MUSCULOSKELETAL ABSCESS'
#  'SUPERFICIAL INJURY; CONTUSION, SUBSEQUENT ENCOUNTER'
#  'STRESS FRACTURE, SUBSEQUENT ENCOUNTER'
#  'ENDOCRINE SYSTEM CANCERS - ALL OTHER TYPES'
#  'ENDOCRINE SYSTEM CANCERS - THYMUS'
#  'COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE, INJURY, SUBSEQUENT ENCOUNTER'
#  'BIRTH TRAUMA' 'OTITIS MEDIA'
#  'SHORT GESTATION; LOW BIRTH WEIGHT; AND FETAL GROWTH RETARDATION'
#  'URINARY INCONTINENCE' 'TUBERCULOSIS'
#  'SEQUELA OF SPECIFIED INFECTIOUS DISEASE CONDITIONS'
#  'COMPLICATION OF INTERNAL ORTHOPEDIC DEVICE OR IMPLANT, SUBSEQUENT ENCOUNTER'
#  'NERVOUS SYSTEM CANCERS - ALL OTHER TYPES'
#  'CHRONIC PHLEBITIS; THROMBOPHLEBITIS AND THROMBOEMBOLISM'
#  'HEAD AND NECK CANCERS - PHARYNGEAL' 'ACQUIRED ABSENCE OF LIMB OR ORGAN'
#  'EFFECT OF OTHER EXTERNAL CAUSES, SUBSEQUENT ENCOUNTER'
#  'JUVENILE ARTHRITIS' 'ANESTHESIA COMPLICATIONS DURING PREGNANCY'
#  'CATARACT AND OTHER LENS DISORDERS'
#  'DIABETES MELLITUS WITHOUT COMPLICATION' 'HEAD AND NECK CANCERS - EYE'
#  'OTHER SPECIFIED INJURY, SUBSEQUENT ENCOUNTER'
#  'NEONATAL ABSTINENCE SYNDROME' 'VESICOURETERAL REFLUX'
#  'ACUTE RHEUMATIC HEART DISEASE'
#  'FEMALE REPRODUCTIVE SYSTEM CANCERS - ALL OTHER TYPES'
#  'EXPOSURE, ENCOUNTERS, SCREENING OR CONTACT WITH INFECTIOUS DISEASE'
#  'AUTOINFLAMMATORY SYNDROMES' 'BIOMECHANICAL LESIONS' 'FEMALE INFERTILITY'
#  'HEAD AND NECK CANCERS - NASOPHARYNGEAL'
#  'COMPLICATION OF CARDIOVASCULAR DEVICE, IMPLANT OR GRAFT, SUBSEQUENT ENCOUNTER'
#  'POSTPROCEDURAL OR POSTOPERATIVE COMPLICATIONS OF THE SPLEEN'
#  'ALLERGIC REACTIONS, SUBSEQUENT ENCOUNTER'
#  'COMPLICATION OF GENITOURINARY DEVICE, IMPLANT OR GRAFT, SUBSEQUENT ENCOUNTER'
#  'CONTRACEPTIVE AND PROCREATIVE MANAGEMENT' 'HEARING LOSS'
#  'ENDOCRINE SYSTEM CANCERS - ADRENOCORTICAL'
#  'ADVERSE EFFECTS OF DRUGS AND MEDICAMENTS, INITIAL ENCOUNTER'
#  'POSTPROCEDURAL OR POSTOPERATIVE EYE COMPLICATION' 'PROTEINURIA'
#  'COMPLICATIONS FOLLOWING ECTOPIC AND/OR MOLAR PREGNANCY'
#  'AMPUTATION OF OTHER BODY PARTS, INITIAL ENCOUNTER'
#  'MENTAL AND SUBSTANCE USE DISORDERS; SEQUELA'
#  'NEONATAL ACIDEMIA AND HYPOXIA' 'NEUROGENIC/NEUROPATHIC ARTHROPATHY'
#  'SPRAINS AND STRAINS, SUBSEQUENT ENCOUNTER' 'INHALANT-RELATED DISORDERS'
#  'SUICIDE ATTEMPT/INTENTIONAL SELF-HARM; SUBSEQUENT ENCOUNTER'
#  'POSTPROCEDURAL OR POSTOPERATIVE EAR AND/OR MASTOID PROCESS COMPLICATION'
#  'STRABISMUS' 'URINARY SYSTEM CANCERS - URETHRA' 'LEUKEMIA - HAIRY CELL'
#  'OTHER SPECIFIED CHRONIC ARTHROPATHY'
#  'POISONING/TOXIC EFFECT/ADVERSE EFFECTS/UNDERDOSING, SEQUELA'
#  'POISONING BY DRUGS, SUBSEQUENT ENCOUNTER'
#  'ENDOCRINE SYSTEM CANCERS - PARATHYROID'
#  'AMPUTATION OF A LIMB, SUBSEQUENT ENCOUNTER' 'REFRACTIVE ERROR'
#  'CHROMOSOMAL ABNORMALITIES' 'ENCOUNTER FOR MENTAL HEALTH CONDITIONS'
#  'DISLOCATIONS, SUBSEQUENT ENCOUNTER'
#  'OPEN WOUNDS OF HEAD AND NECK, SUBSEQUENT ENCOUNTER'
#  'OPEN WOUNDS OF TRUNK, SUBSEQUENT ENCOUNTER'
#  'NEWBORN AFFECTED BY MATERNAL CONDITIONS OR COMPLICATIONS OF LABOR/DELIVERY'
#  'FETAL ALCOHOL SYNDROME' 'ATYPICAL FRACTURE, SUBSEQUENT ENCOUNTER'
#  'ENDOCRINE SYSTEM CANCERS - PITUITARY GLAND'
#  'OTHER SPECIFIED ENCOUNTERS AND COUNSELING'
#  'MALTREATMENT/ABUSE, SUBSEQUENT ENCOUNTER' 'OSTEOMALACIA'
#  'EFFECT OF FOREIGN BODY ENTERING OPENING, SUBSEQUENT ENCOUNTER'
#  'INJURY TO BLOOD VESSELS, SUBSEQUENT ENCOUNTER'
#  'OTHER UNSPECIFIED INJURIES, SUBSEQUENT ENCOUNTER' 'ANTENATAL SCREENING'
#  'LIFESTYLE/LIFE MANAGEMENT FACTORS']
# ccsr_procedure_description : ['ISOLATION PROCEDURES' nan 'CESAREAN SECTION'
#  'ADMINISTRATION OF NUTRITIONAL AND ELECTROLYTIC SUBSTANCES'
#  'LUMBAR PUNCTURE' 'COMPUTERIZED TOMOGRAPHY (CT) WITHOUT CONTRAST'
#  'VACCINATIONS' 'LARYNGOSCOPY (DIAGNOSTIC)'
#  'ADMINISTRATION OF THERAPEUTIC SUBSTANCES, NEC'
#  'BONE FIXATION (EXCLUDING EXTREMITIES)' 'CHEMOTHERAPY'
#  'VENOUS AND ARTERIAL CATHETER PLACEMENT'
#  'TRANSFUSION OF BLOOD AND BLOOD PRODUCTS' 'ADMINISTRATION OF ANTIBIOTICS'
#  'CIRCUMCISION' 'DIAGNOSTIC AUDIOLOGY' 'POTENTIAL COVID-19 THERAPIES'
#  'PROSTATECTOMY' 'SUBCUTANEOUS TISSUE, FASCIA, AND MUSCLE BIOPSY'
#  'PERCUTANEOUS CORONARY INTERVENTIONS (PCI)'
#  'PHARMACOTHERAPY FOR MENTAL HEALTH (EXCLUDING SUBSTANCE USE)'
#  'SPONTANEOUS VAGINAL DELIVERY' 'COLECTOMY' 'NON-INVASIVE VENTILATION'
#  'GASTROSTOMY' 'ULTRASONOGRAPHY'
#  'OTHER CARDIOVASCULAR SYSTEM MEASUREMENT AND MONITORING'
#  'CARDIAC AND CORONARY FLUOROSCOPY' 'CARDIOVERSION'
#  'GASTRO-JEJUNAL BYPASS (INCLUDING BARIATRIC)' 'HEMODIALYSIS'
#  'ADMINISTRATION OF ANTI-INFLAMMATORY AGENTS'
#  'JOINT FUSION (EXCLUDING SPINE)'
#  'COMMON BILE DUCT SPHINCTEROTOMY AND STENTING' 'PHOTOTHERAPY'
#  'PARACENTESIS' 'MECHANICAL VENTILATION' 'APPENDECTOMY' 'GASTRECTOMY'
#  'RH IMMUNOGLOBULIN AND OTHER SERUM INFUSION'
#  'GI SYSTEM ENDOSCOPY WITHOUT BIOPSY (DIAGNOSTIC)'
#  'SKIN LACERATION REPAIR (EXCLUDING PERINEUM)'
#  'HEART CONDUCTION MECHANISM PROCEDURES'
#  'PACEMAKER AND DEFIBRILLATOR INTERROGATION' 'DIAPHRAGMATIC HERNIA REPAIR'
#  'ELECTROENCEPHALOGRAM (EEG)'
#  'REMOVAL OF PLACENTA AND OTHER RETAINED PRODUCTS OF CONCEPTION'
#  'NAIL PROCEDURES' 'CARDIAC MONITORING'
#  'PERIPHERAL ARTERIAL BYPASS PROCEDURES' 'FETAL HEART RATE MONITORING'
#  'LUMBOSACRAL NERVE DECOMPRESSION' 'FEMALE UPPER GENITAL TRACT EXCISION'
#  'SMALL BOWEL RESECTION'
#  'PHYSICAL, OCCUPATIONAL, AND RESPIRATORY THERAPY TREATMENT'
#  'REGIONAL ANESTHESIA' 'ELECTROCARDIOGRAM (ECG)'
#  'ABDOMINAL WALL REPAIR (INCLUDING HERNIA)' 'HIP ARTHROPLASTY'
#  'FRENECTOMY' 'SPINAL CORD DECOMPRESSION'
#  'CAROTID ENDARTERECTOMY AND STENTING'
#  'LUNG, PLEURA, OR DIAPHRAGM RESECTION (OPEN AND THORACOSCOPIC)'
#  'SUBCUTANEOUS TISSUE AND FASCIA EXCISION'
#  'PSYCHOTHERAPY FOR MENTAL HEALTH (EXCLUDING SUBSTANCE USE)'
#  'FLUOROSCOPY OF NON-CIRCULATORY ORGANS'
#  'PLACEMENT OF TUNNELED OR IMPLANTABLE PORTION OF A VASCULAR ACCESS DEVICE'
#  'LIGATION AND EMBOLIZATION OF VESSELS' 'MENTAL HEALTH PROCEDURES, NEC'
#  'REMOVAL OF ECTOPIC PREGNANCY'
#  'ESOPHAGOGASTRODUODENOSCOPY (EGD) WITH BIOPSY'
#  'CHEST TUBE PLACEMENT AND THERAPEUTIC THORACENTESIS'
#  'INCISION AND DRAINAGE OF SUBCUTANEOUS TISSUE AND FASCIA'
#  'TONSILLECTOMY AND ADENOIDECTOMY' 'HEPATOBILIARY AND PANCREATIC DRAINAGE'
#  'BLADDER CATHETERIZATION AND DRAINAGE' 'FEMUR FIXATION' 'CHOLECYSTECTOMY'
#  'PHYSICAL, OCCUPATIONAL, AND RESPIRATORY THERAPY EVALUATION'
#  'MEASUREMENT DURING CARDIAC CATHETERIZATION' 'KNEE ARTHROPLASTY'
#  'CYSTOSCOPY AND URETEROSCOPY (INCLUDING BIOPSY)'
#  'ANGIOPLASTY AND RELATED VESSEL PROCEDURES (ENDOVASCULAR; EXCLUDING CAROTID)'
#  'FIXATION OF LEG AND FOOT BONES' 'OTHER PERITONEAL CAVITY PROCEDURES'
#  'TRANSFUSION OF PLASMA' 'URETER AND OTHER URINARY TRACT DILATION'
#  'INTRAVENOUS INDUCTION OF LABOR'
#  'UPPER GI THERAPEUTIC PROCEDURES, NEC (ENDOSCOPIC)'
#  'ADMINISTRATION OF THROMBOLYTICS AND PLATELET INHIBITORS' 'TRACHEOSTOMY'
#  'BRONCHOSCOPY (THERAPEUTIC)' 'KIDNEY TRANSPLANT'
#  'ENT DIAGNOSTIC PROCEDURES (NON-ENDOSCOPIC)' 'HYSTERECTOMY'
#  'SALPINGECTOMY' 'BILIARY AND PANCREATIC CALCULUS REMOVAL'
#  'FLUOROSCOPIC ANGIOGRAPHY (EXCLUDING CORONARY)'
#  'SUBSTANCE USE DETOXIFICATION'
#  'LOWER GI THERAPEUTIC PROCEDURES, NEC (EXCLUDING OPEN AND LAPAROSCOPIC)'
#  'VULVAR LACERATION REPAIR'
#  'SUBCUTANEOUS TISSUE AND FASCIA PROCEDURES, NEC'
#  'INGUINAL AND FEMORAL HERNIA REPAIR'
#  'PENIS PROCEDURES (EXCLUDING CIRCUMCISION)'
#  'CEREBROSPINAL FLUID SHUNT PROCEDURES' 'SPINE FUSION'
#  'OTHER CNS DRAINAGE AND RELATED PROCEDURES'
#  'REMOVAL OF CALCULI AND OTHER MATTER FROM URINARY TRACT'
#  'MUSCULOSKELETAL PROCEDURES, NEC'
#  'PORTAL AND OTHER VENOUS BYPASS PROCEDURES' 'CNS PROCEDURES, NEC'
#  'MAGNETIC RESONANCE IMAGING (MRI)'
#  'PROSTATE AND SEMINAL VESICLE PROCEDURES (EXCLUDING PROSTATECTOMY)'
#  'MASTECTOMY AND LUMPECTOMY' 'BREAST RECONSTRUCTION' 'LYMPH NODE BIOPSY'
#  'MALE REPRODUCTIVE SYSTEM PROCEDURES, NEC'
#  'FLUOROSCOPIC GUIDANCE FOR CIRCULATORY SYSTEM PROCEDURES'
#  'AIRWAY INTUBATION' 'INCISION AND DRAINAGE OF SKIN'
#  'ENT DRAINAGE (EXCLUDING MYRINGOTOMY)'
#  'GI SYSTEM DRAINAGE (EXCLUDING PARACENTESIS)'
#  'CYSTECTOMY (INCLUDING FULGURATION) AND URETHRECTOMY'
#  'NEPHROSTOMY AND URETEROSTOMY PROCEDURES (INCLUDING STENTS)'
#  'COLONOSCOPY AND PROCTOSCOPY WITH BIOPSY' 'THORACENTESIS (DIAGNOSTIC)'
#  'IMMOBILIZATION BY SPLINT OR OTHER EXTERNAL DEVICE'
#  'BONE AND JOINT BIOPSY'
#  'PERINEAL SKIN REPAIR (1ST DEGREE OBSTETRICAL AND OTHER)' 'SPLENECTOMY'
#  'PHARMACOTHERAPY FOR SUBSTANCE USE' 'CERVICAL CERCLAGE'
#  'FIXATION OF UPPER EXTREMITY BONES'
#  'HEART VALVE REPLACEMENT AND OTHER VALVE PROCEDURES (ENDOVASCULAR)'
#  'UPPER GI THERAPEUTIC PROCEDURES, NEC (OPEN AND LAPAROSCOPIC)'
#  'LYMPH NODE EXCISION (THERAPEUTIC)' 'ASSISTED VAGINAL DELIVERY'
#  'URINARY SYSTEM PROCEDURES, NEC' 'ENT REPAIR' 'MENINGES REPAIR'
#  'NEPHRECTOMY AND URETERECTOMY' 'PREGNANCY AND FETAL PROCEDURES, NEC'
#  'SPINAL EPIDURAL CATHETER PLACEMENT' 'PLAIN RADIOGRAPHY'
#  'DENTAL PROCEDURES' 'SKIN BIOPSY AND DIAGNOSTIC DRAINAGE'
#  'HEPATOBILIARY AND PANCREATIC PROCEDURES, NEC'
#  'PERINEAL MUSCLE LACERATION REPAIR (2ND DEGREE OBSTETRICAL AND OTHER)'
#  'ILEOSTOMY AND COLOSTOMY' 'LEFT ATRIAL APPENDAGE PROCEDURES'
#  'ARTHROCENTESIS' 'BONE MARROW BIOPSY' 'RETROPERITONEAL PROCEDURES, NEC'
#  'RADIATION THERAPY, NEC' 'FEMALE REPRODUCTIVE SYSTEM PROCEDURES, NEC'
#  'GI SYSTEM REPAIR (EXCLUDING ANORECTAL)' 'SKIN GRAFT'
#  'PANCREATIC AND PROXIMAL BILIARY DILATION AND STENTING' 'BONE EXCISION'
#  'CERVICAL DILATION' 'HEART ASSIST DEVICE PROCEDURES'
#  'TOE AND MID FOOT AMPUTATION' 'PROCTECTOMY OR ANAL RESECTION'
#  'PACEMAKER AND DEFIBRILLATOR PROCEDURES'
#  'CORONARY ARTERY BYPASS GRAFTS (CABG)' 'ANEURYSM REPAIR PROCEDURES'
#  'EYE PROCEDURES' 'ABORTION'
#  'ADMINISTRATION OF DIAGNOSTIC SUBSTANCES, NEC'
#  'PERIPHERAL ARTERIOVENOUS FISTULA AND SHUNT PROCEDURES'
#  'LOWER GI THERAPEUTIC PROCEDURES, NEC (OPEN AND LAPAROSCOPIC)'
#  'PERICARDIAL PROCEDURES' 'SKIN EXCISION AND DEBRIDEMENT' 'LIVER BIOPSY'
#  'COMPUTERIZED TOMOGRAPHY (CT) WITH CONTRAST' 'CARDIAC STRESS TESTS'
#  'FEMALE GENITAL TRACT REPAIR (EXCLUDING VULVA)'
#  'CLOSED REDUCTION OF BONES AND JOINTS' 'URINARY TRACT REPAIR'
#  'INTRAUTERINE DEVICE (IUD) INSERTION' 'THYROIDECTOMY'
#  'PACKING AND DRESSING PROCEDURES'
#  'MUSCULOSKELETAL DEVICE PROCEDURES, NEC' 'PHERESIS THERAPY'
#  'OTHER GI SYSTEM DEVICE PROCEDURES'
#  'INTRACRANIAL EPIDURAL AND SUBDURAL SPACE DRAINAGE'
#  'ABOVE KNEE AND OTHER PROXIMAL LOWER EXTREMITY AMPUTATION'
#  'CONTROL OF BLEEDING (NON-ENDOSCOPIC)' 'CNS EXCISION PROCEDURES'
#  'BELOW KNEE AMPUTATION' 'EYELID PROCEDURES'
#  'CARDIOVASCULAR DEVICE PROCEDURES, NEC'
#  'FINGER AND OTHER UPPER EXTREMITY AMPUTATION'
#  'ENDOSCOPIC CONTROL OF BLEEDING' 'COSMETIC PROCEDURES'
#  'IRRIGATION (DIAGNOSTIC AND THERAPEUTIC)' 'VERTEBRAL DISCECTOMY'
#  'CHEST WALL PROCEDURES, NEC'
#  'INCISION AND DRAINAGE OF MUSCULOSKELETAL TISSUE AND JOINTS'
#  'BRONCHOSCOPY (DIAGNOSTIC)'
#  'ARTERY, VEIN, AND GREAT VESSEL PROCEDURES, NEC'
#  'INFUSION OF VASOPRESSOR' 'GI SYSTEM LYSIS OF ADHESIONS'
#  'ABDOMINAL WALL PROCEDURES, NEC' 'TOMOGRAPHIC NUCLEAR MEDICINE IMAGING'
#  'EPISIOTOMY' 'DECOMPRESSIVE CRANIECTOMY' 'COUNSELING FOR SUBSTANCE USE'
#  'ARTHROPLASTY OF OTHER JOINT (EXCLUDING KNEE AND HIP)'
#  'VESSEL REPAIR AND REPLACEMENT' 'ULTRAVIOLET LIGHT THERAPY'
#  'OOPHORECTOMY' 'JOINT TISSUE EXCISION (EXCLUDING DISCECTOMY)'
#  'MUSCLE, TENDON, BURSA, AND LIGAMENT EXCISION'
#  'TENDON, MUSCLE, BURSA, AND LIGAMENT REPAIR (EXCLUDING PERINEAL)'
#  'PERIPHERAL NERVE DECOMPRESSION (EXCLUDING LUMBOSACRAL AND CERVICOTHORACIC)'
#  'KIDNEY AND OTHER URINARY TRACT BIOPSY (NON-ENDOSCOPIC)'
#  'HEART VALVE REPLACEMENT AND OTHER VALVE PROCEDURES (NON-ENDOVASCULAR)'
#  'INFERIOR VENA CAVA (IVC) FILTER PROCEDURES'
#  'GI SYSTEM ENDOSCOPIC THERAPEUTIC PROCEDURES'
#  'CNS NEUROSTIMULATOR PROCEDURES'
#  'ANORECTAL REPAIR (3RD AND 4TH DEGREE OBSTETRICAL REPAIRS AND OTHER)'
#  'RESPIRATORY SYSTEM PROCEDURES, NEC' 'EXPLORATION OF PERITONEAL CAVITY'
#  'MEDIASTINAL PROCEDURES, NEC' 'DIAGNOSTIC ERCP WITH OR WITHOUT BIOPSY'
#  'OMENTECTOMY OR PERITONEUM RESECTION' 'GI SYSTEM BIOPSY (NON-ENDOSCOPIC)'
#  'PANCREATECTOMY' 'LUNG, PLEURA, OR DIAPHRAGM BIOPSY (NON-ENDOSCOPIC)'
#  'PITUITARY GLAND RESECTION' 'SALIVARY GLAND EXCISION'
#  'SEPTAL REPAIR AND OTHER THERAPEUTIC HEART PROCEDURES' 'HEART TRANSPLANT'
#  'CARDIAC CHEST COMPRESSION' 'ADMINISTRATION OF ALBUMIN AND GLOBULIN'
#  'CARDIAC ASSISTANCE WITH BALLOON PUMP' 'TRANSFUSION OF CLOTTING FACTORS'
#  'EMBOLECTOMY, ENDARTERECTOMY, AND RELATED VESSEL PROCEDURES (NON-ENDOVASCULAR; EXCLUDING CAROTID)'
#  'ENT DIAGNOSTIC ENDOSCOPY (EXCLUDING LARYNGOSCOPY)'
#  'MALE PERINEUM PROCEDURES' 'LYMPH NODE DISSECTION'
#  'ENT EXCISION (EXCLUDING NASAL PASSAGE, SINUSES, TONGUE, SALIVARY GLANDS, LARYNX)'
#  'ELECTROCONVULSIVE THERAPY' 'PERITONEAL DIALYSIS'
#  'POSITRON EMISSION TOMOGRAPHIC (PET) IMAGING'
#  'PSYCHOTHERAPY FOR SUBSTANCE USE' 'CERVICAL RIPENING'
#  'PERIPHERAL ARTERIAL PRESSURE MONITORING'
#  'HEPATOBILIARY RESECTION AND ABLATION'
#  'SAPHENOUS VEIN HARVEST AND OTHER THERAPEUTIC VESSEL REMOVAL'
#  'ROBOTIC-ASSISTED PROCEDURES' 'COMPUTER-ASSISTED PROCEDURES'
#  'ELECTROPHYSIOLOGIC STUDIES' 'OPEN AND THORACOSCOPIC PLEURAL DRAINAGE'
#  'FALLOPIAN TUBE LIGATION AND EXCISION' 'NERVE REPAIR'
#  'MEASUREMENT AND MONITORING, NEC' 'LIVER TRANSPLANT'
#  'ADMINISTRATION AND TRANSFUSION OF BONE MARROW, STEM CELLS, PANCREATIC ISLET CELLS, AND T-CELLS'
#  'THYMECTOMY' 'ENT PROCEDURES, NEC' 'SKIN AND BREAST PROCEDURES, NEC'
#  'SPEECH THERAPY TREATMENT' 'PARATHYROIDECTOMY'
#  'RELEASE OF LUNG AND PLEURA' 'ADRENALECTOMY' 'TRACHELECTOMY'
#  'VENTRICULOSTOMY [PERCUTANEOUS APPROACH]' 'STEREOTACTIC RADIOSURGERY'
#  'BRONCHOSCOPIC EXCISION AND FULGURATION' 'MINIMALLY INVASIVE CNS BIOPSY'
#  'LUNG TRANSPLANT' 'URINARY DIVERSION WITH ANASTOMOSIS OR OSTOMY'
#  'HEART AND GREAT VESSEL BYPASS PROCEDURES'
#  'EXTRACORPOREAL MEMBRANE OXYGENATION'
#  'SUBCUTANEOUS CONTRACEPTIVE IMPLANT' 'CARDIAC PACING' 'TONGUE EXCISION'
#  'LARYNGECTOMY' 'FEMALE LOWER GENITAL TRACT EXCISION'
#  'PANCREATICOBILIARY BIOPSY' 'ENDOCRINE SYSTEM BIOPSY' 'MYRINGOTOMY'
#  'OTHER CORONARY ARTERY PROCEDURES (EXCLUDING CABG AND PCI)'
#  'ICP AND OTHER CNS MONITORING (EXCLUDING EEG)' 'BEAM RADIATION'
#  'PULMONARY ARTERIAL PRESSURE MONITORING' 'DUODENAL RESECTION'
#  'ESOPHAGECTOMY' 'PANCREAS TRANSPLANT' 'PERIPHERAL NERVE DENERVATION'
#  'NASAL AND SINUS EXCISION'
#  'SPINAL CANAL AND SPINAL CORD DRAINAGE (EXCLUDING LUMBAR PUNCTURE)'
#  'CRISIS INTERVENTION FOR MENTAL HEALTH' 'PLANAR NUCLEAR MEDICINE IMAGING'
#  'HYPERBARIC OXYGEN THERAPY' 'HYPOTHERMIA THERAPY'
#  'BONE MARROW ASPIRATION (THERAPEUTIC)'
#  'EXTRACORPOREAL OR SYSTEMIC THERAPIES, NEC'
#  'PERIPHERAL NERVE PROCEDURES, NEC' 'HEART BIOPSY' 'BRACHYTHERAPY'
#  'MONITORING OF PERIPHERAL NERVES' 'ENDOCRINE PROCEDURES, NEC'
#  'ARTERIAL OXYGEN SATURATION MONITORING'
#  'CERVICOTHORACIC NERVE DECOMPRESSION' 'OPEN HEART CARDIOPULMONARY BYPASS'
#  'SPEECH THERAPY EVALUATION' 'SPLEEN PROCEDURES (EXCLUDING SPLENECTOMY)'
#  'LYMPHATIC PROCEDURES, NEC' 'THERAPEUTIC MASSAGE AND RELATED PROCEDURES'
#  'FLUORESCENCE IMAGING'
#  'CARDIAC ASSISTANCE WITH VENTRICULAR ASSIST DEVICE' 'GI TRANSPLANT'
#  'RADIONUCLIDE THERAPY AND NON-IMAGING PROCEDURES'
#  'GENITOURINARY TRACT PROCEDURES, NEC' 'PULMONARY FUNCTION TESTS'
#  'OSTEOPATHIC TREATMENT' 'CHIROPRACTIC MANIPULATION'
#  'OVARY OR UTERUS TRANSPLANT']
# apr_drg_description : ['MAJOR RESPIRATORY INFECTIONS AND INFLAMMATIONS'
#  'MULTIPLE SCLEROSIS, OTHER DEMYELINATING DISEASE AND INFLAMMATORY NEUROPATHIES'
#  'CESAREAN SECTION WITHOUT STERILIZATION'
#  'KIDNEY AND URINARY TRACT INFECTIONS' 'OTHER DISORDERS OF NERVOUS SYSTEM'
#  'OTHER COMPLICATIONS OF TREATMENT'
#  'HEAD TRAUMA WITH COMA > 1 HOUR OR HEMORRHAGE'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS, NORMAL NEWBORN OR NEONATE WITH OTHER PROBLEM'
#  'POST-OPERATIVE, POST-TRAUMATIC, OTHER DEVICE INFECTIONS'
#  'OTHER GASTROENTERITIS, NAUSEA AND VOMITING' 'ASTHMA' 'DIABETES'
#  'SICKLE CELL ANEMIA CRISIS' 'CHRONIC OBSTRUCTIVE PULMONARY DISEASE'
#  'OTHER ANEMIA AND DISORDERS OF BLOOD AND BLOOD-FORMING ORGANS'
#  'CERVICAL SPINAL FUSION AND OTHER BACK OR NECK PROCEDURES EXCEPT DISC EXCISION OR DECOMPRESSION'
#  'OTHER CHEMOTHERAPY' 'PERIPHERAL, CRANIAL AND AUTONOMIC NERVE DISORDERS'
#  'MALFUNCTION, REACTION, COMPLICATION OF GENITOURINARY DEVICE OR PROCEDURE'
#  'INTESTINAL OBSTRUCTION' 'SEIZURE' 'CESAREAN SECTION WITH STERILIZATION'
#  'OTHER MALE REPRODUCTIVE SYSTEM AND RELATED PROCEDURES' 'SCHIZOPHRENIA'
#  'PERCUTANEOUS CARDIAC INTERVENTION WITHOUT AMI'
#  'ALCOHOL ABUSE AND DEPENDENCE' 'VAGINAL DELIVERY'
#  'CVA AND PRECEREBRAL OCCLUSION WITH INFARCTION'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH CONGENITAL OR PERINATAL INFECTION'
#  'MAJOR LARGE BOWEL PROCEDURES'
#  'MULTIPLE SIGNIFICANT TRAUMA WITHOUT O.R. PROCEDURE'
#  'SEPTICEMIA AND DISSEMINATED INFECTIONS' 'HEART FAILURE'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS, NORMAL NEWBORN OR NEONATE WITH OTHER PROBLEM'
#  'ACUTE ANXIETY AND DELIRIUM STATES'
#  'CARDIAC CATHETERIZATION FOR OTHER NON-CORONARY CONDITIONS'
#  'ACUTE MYOCARDIAL INFARCTION' 'PULMONARY EMBOLISM'
#  'MIGRAINE AND OTHER HEADACHES' 'PROCEDURES FOR OBESITY'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH OTHER SIGNIFICANT CONDITION'
#  'SIGNS, SYMPTOMS AND OTHER FACTORS INFLUENCING HEALTH STATUS'
#  'NON-HYPOVOLEMIC SODIUM DISORDERS'
#  'OTHER BACK AND NECK DISORDERS, FRACTURES AND INJURIES'
#  'FOOT AND TOE PROCEDURES' 'LYMPHOMA, MYELOMA AND NON-ACUTE LEUKEMIA'
#  'DISORDERS OF GALLBLADDER AND BILIARY TRACT'
#  'TOXIC EFFECTS OF NON-MEDICINAL SUBSTANCES' 'DIGESTIVE MALIGNANCY'
#  'MALFUNCTION, REACTION AND COMPLICATION OF GASTROINTESTINAL DEVICE OR PROCEDURE'
#  'DIVERTICULITIS AND DIVERTICULOSIS'
#  'DRUG AND ALCOHOL ABUSE OR DEPENDENCE, LEFT AGAINST MEDICAL ADVICE'
#  'APPENDECTOMY WITHOUT COMPLEX PRINCIPAL DIAGNOSIS' 'BIPOLAR DISORDERS'
#  'POISONING OF MEDICINAL AGENTS'
#  'VAGINAL DELIVERY WITH STERILIZATION AND/OR D&C'
#  'OTHER DRUG ABUSE AND DEPENDENCE'
#  'CONTUSION, OPEN WOUND AND OTHER TRAUMA TO SKIN AND SUBCUTANEOUS TISSUE'
#  'OTHER PNEUMONIA' 'CARDIAC ARRHYTHMIA AND CONDUCTION DISORDERS'
#  'OTHER NON-HYPOVOLEMIC ELECTROLYTE DISORDERS'
#  'HIV WITH MULTIPLE MAJOR HIV RELATED CONDITIONS'
#  'HIV WITH MULTIPLE SIGNIFICANT HIV RELATED CONDITIONS'
#  'SYNCOPE AND COLLAPSE' 'PEPTIC ULCER AND GASTRITIS'
#  'FRACTURES AND DISLOCATIONS EXCEPT FEMUR, PELVIS AND BACK'
#  'MAJOR STOMACH, ESOPHAGEAL AND DUODENAL PROCEDURES'
#  'MAJOR DEPRESSIVE DISORDERS AND OTHER OR UNSPECIFIED PSYCHOSES'
#  'TRANSIENT ISCHEMIA'
#  'ABORTION WITH D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY'
#  'MENSTRUAL AND OTHER FEMALE REPRODUCTIVE SYSTEM DISORDERS'
#  'ALLERGIC REACTIONS'
#  'OTHER MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE DIAGNOSES'
#  'ACUTE KIDNEY INJURY' 'CELLULITIS AND OTHER SKIN INFECTIONS'
#  'DEPRESSION EXCEPT MAJOR DEPRESSIVE DISORDER'
#  'OPIOID ABUSE AND DEPENDENCE' 'RESPIRATORY FAILURE'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH MAJOR ANOMALY'
#  'MAJOR ABDOMINAL VASCULAR PROCEDURES'
#  'ADJUSTMENT DISORDERS AND NEUROSES EXCEPT DEPRESSIVE DIAGNOSES'
#  'ANTEPARTUM WITHOUT O.R. PROCEDURE'
#  'EYE INFECTIONS AND OTHER EYE DISORDERS'
#  'OTHER DIGESTIVE SYSTEM DIAGNOSES' 'HIV WITH MAJOR HIV RELATED CONDITION'
#  'INTERVERTEBRAL DISC EXCISION AND DECOMPRESSION'
#  'OTHER DISORDERS OF THE LIVER'
#  'VAGINAL DELIVERY WITH O.R. PROCEDURE EXCEPT STERILIZATION AND/OR D&C'
#  'CHEMOTHERAPY FOR ACUTE LEUKEMIA'
#  'UTERINE AND ADNEXA PROCEDURES FOR LEIOMYOMA'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH OR WITHOUT OTHER SIGNIFICANT CONDITION'
#  'MAJOR SMALL BOWEL PROCEDURES' 'BRONCHIOLITIS AND RSV PNEUMONIA'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH MAJOR ANOMALY'
#  'POSTPARTUM AND POST ABORTION DIAGNOSES WITHOUT PROCEDURE'
#  'REHABILITATION'
#  'HERNIA PROCEDURES EXCEPT INGUINAL, FEMORAL AND UMBILICAL'
#  'AMPUTATION OF LOWER LIMB EXCEPT TOES' 'ELECTIVE HIP JOINT REPLACEMENT'
#  'OSTEOMYELITIS, SEPTIC ARTHRITIS AND OTHER MUSCULOSKELETAL INFECTIONS'
#  'OPEN EXTRACRANIAL VASCULAR PROCEDURES'
#  'DEGENERATIVE NERVOUS SYSTEM DISORDERS EXCEPT MULTIPLE SCLEROSIS'
#  'OTHER MENTAL HEALTH DISORDERS' 'MAJOR RESPIRATORY AND CHEST PROCEDURES'
#  'OTHER RESPIRATORY DIAGNOSES EXCEPT SIGNS, SYMPTOMS AND MISCELLANEOUS DIAGNOSES'
#  'POST-OPERATIVE, POST-TRAUMA, OTHER DEVICE INFECTIONS WITH O.R. PROCEDURE'
#  'INTERSTITIAL AND ALVEOLAR LUNG DISEASES'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH OTHER SIGNIFICANT CONDITION'
#  'ALTERATION IN CONSCIOUSNESS' 'DISORDERS OF PANCREAS EXCEPT MALIGNANCY'
#  'OTHER ESOPHAGEAL DISORDERS'
#  'URINARY STONES AND ACQUIRED UPPER URINARY TRACT OBSTRUCTION'
#  'CHRONIC KIDNEY DISEASE' 'RESPIRATORY MALIGNANCY'
#  'LYMPHATIC AND OTHER MALIGNANCIES AND NEOPLASMS OF UNCERTAIN BEHAVIOR'
#  'PERCUTANEOUS INTRACRANIAL AND EXTRACRANIAL VASCULAR PROCEDURES'
#  'CARDIAC ARREST AND SHOCK'
#  'ABORTION WITHOUT D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY'
#  'MODERATELY EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'TONSIL AND ADENOID PROCEDURES'
#  'OTHER KIDNEY AND URINARY TRACT DIAGNOSES, SIGNS AND SYMPTOMS'
#  'MAJOR O.R. PROCEDURES FOR LYMPHATIC, HEMATOPOIETIC OR OTHER NEOPLASMS'
#  'MAJOR SKIN DISORDERS' 'CHOLECYSTECTOMY'
#  'PERIPHERAL AND OTHER VASCULAR DISORDERS' 'HYPERTENSION'
#  'ALCOHOL AND DRUG DEPENDENCE WITH REHABILITATION AND/OR DETOXIFICATION THERAPY'
#  'DISORDERS OF PERSONALITY AND IMPULSE CONTROL'
#  'MAJOR CHEST AND RESPIRATORY TRAUMA'
#  'NEONATE BIRTH WEIGHT 1000-1249 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CON'
#  'OTHER CIRCULATORY SYSTEM DIAGNOSES' 'ELECTIVE KNEE JOINT REPLACEMENT'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CON'
#  'COCAINE ABUSE AND DEPENDENCE' 'HIP AND FEMUR FRACTURE REPAIR'
#  'MAJOR ESOPHAGEAL DISORDERS'
#  'HIV WITH ONE SIGNIFICANT HIV CONDITION OR WITHOUT SIGNIFICANT RELATED CONDITIONS'
#  'ACUTE LEUKEMIA' 'OTHER BLADDER PROCEDURES'
#  'VERTIGO AND OTHER LABYRINTH DISORDERS'
#  'OTHER CIRCULATORY SYSTEM PROCEDURES'
#  'KNEE AND LOWER LEG PROCEDURES EXCEPT FOOT'
#  'OTHER DIGESTIVE SYSTEM AND ABDOMINAL PROCEDURES'
#  'OTHER INFECTIOUS AND PARASITIC DISEASES'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CON'
#  'KIDNEY AND URINARY TRACT PROCEDURES FOR NON-MALIGNANCY'
#  'INTENTIONAL SELF-HARM AND ATTEMPTED SUICIDE'
#  'MALE REPRODUCTIVE SYSTEM DIAGNOSES EXCEPT MALIGNANCY' 'CHEST PAIN'
#  'TRACHEOSTOMY WITH MV >96 HOURS WITH EXTENSIVE PROCEDURE'
#  'KIDNEY TRANSPLANT' 'CARDIAC STRUCTURAL AND VALVULAR DISORDERS'
#  'ALCOHOLIC LIVER DISEASE'
#  'OTHER AND UNSPECIFIED GASTROINTESTINAL HEMORRHAGE'
#  'MAJOR MALE PELVIC PROCEDURES' 'BEHAVIORAL DISORDERS'
#  'CARDIAC CATHETERIZATION FOR CORONARY ARTERY DISEASE'
#  'ANTEPARTUM WITH O.R. PROCEDURE' 'OTHER RESPIRATORY AND CHEST PROCEDURES'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CONDIT'
#  'OTHER PERIPHERAL VASCULAR PROCEDURES'
#  'RESPIRATORY SYSTEM DIAGNOSIS WITH VENTILATOR SUPPORT > 96 HOURS'
#  'RESPIRATORY SIGNS, SYMPTOMS AND MISCELLANEOUS DIAGNOSES'
#  'MALIGNANT BREAST DISORDERS' 'FEMALE REPRODUCTIVE SYSTEM INFECTIONS'
#  'INGUINAL, FEMORAL AND UMBILICAL HERNIA PROCEDURES'
#  'OTHER EAR, NOSE, MOUTH, THROAT AND CRANIAL OR FACIAL DIAGNOSES'
#  'PENIS, TESTES AND SCROTAL PROCEDURES' 'VENTRICULAR SHUNT PROCEDURES'
#  'EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'NEONATE BIRTH WEIGHT 500-749 GRAMS WITHOUT MAJOR PROCEDURE'
#  'OPEN CRANIOTOMY EXCEPT TRAUMA' 'URETHRAL AND TRANSURETHRAL PROCEDURES'
#  'TENDON, MUSCLE AND OTHER SOFT TISSUE PROCEDURES'
#  'CONNECTIVE TISSUE DISORDERS'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH MAJOR ANOMALY'
#  'ANGINA PECTORIS AND CORONARY ATHEROSCLEROSIS'
#  'OTHER SKIN, SUBCUTANEOUS TISSUE AND RELATED PROCEDURES'
#  'NEONATE BIRTH WEIGHT 2000-2499 GRAMS WITH CONGENITAL OR PERINATAL INFECTION'
#  'TRANSURETHRAL PROSTATECTOMY' 'MASTECTOMY PROCEDURES'
#  'NEONATE BIRTH WEIGHT 1250-1499 GRAMS WITH RESPIRATORY DISTRESS SYNDROME OR OTHER MAJOR RESPIRATORY CON'
#  'UTERINE AND ADNEXA PROCEDURES FOR NON-MALIGNANCY EXCEPT LEIOMYOMA'
#  'NEONATE BIRTH WEIGHT 750-999 GRAMS WITHOUT MAJOR PROCEDURE'
#  'NEPHRITIS AND NEPHROSIS' 'OTHER SIGNIFICANT HIP AND FEMUR SURGERY'
#  'OTHER EAR, NOSE, MOUTH AND THROAT PROCEDURES'
#  'OTHER AFTERCARE AND CONVALESCENCE'
#  'OTHER SKIN, SUBCUTANEOUS TISSUE AND BREAST DISORDERS'
#  'OTHER FEMALE REPRODUCTIVE SYSTEM AND RELATED PROCEDURES'
#  'INFECTIONS OF UPPER RESPIRATORY TRACT'
#  'MALNUTRITION, FAILURE TO THRIVE AND OTHER NUTRITIONAL DISORDERS'
#  'OTHER SMALL AND LARGE BOWEL PROCEDURES' 'SKIN ULCERS'
#  'ACUTE BRONCHITIS AND RELATED SYMPTOMS'
#  'COAGULATION AND PLATELET DISORDERS'
#  'INFECTIOUS AND PARASITIC DISEASES INCLUDING HIV WITH O.R. PROCEDURE'
#  'HEPATIC COMA AND OTHER MAJOR ACUTE LIVER DISORDERS'
#  'DORSAL AND LUMBAR FUSION PROCEDURE EXCEPT FOR CURVATURE OF BACK'
#  'MALIGNANCY, MALE REPRODUCTIVE SYSTEM'
#  'OTHER MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE PROCEDURES'
#  'NON-ELECTIVE OR COMPLEX HIP JOINT REPLACEMENT'
#  'SHOULDER, UPPER ARM AND FOREARM PROCEDURES EXCEPT JOINT REPLACEMENT'
#  'INTRACRANIAL HEMORRHAGE' 'LOWER EXTREMITY ARTERIAL PROCEDURES'
#  'PERCUTANEOUS STRUCTURAL CARDIAC PROCEDURES'
#  'DORSAL AND LUMBAR FUSION PROCEDURE FOR CURVATURE OF BACK'
#  'FACIAL BONE PROCEDURES EXCEPT MAJOR CRANIAL OR FACIAL BONE PROCEDURES'
#  'MAJOR BLADDER PROCEDURES'
#  'BPD AND OTHER CHRONIC RESPIRATORY DISEASES ARISING IN PERINATAL PERIOD'
#  'CLEFT LIP AND PALATE REPAIR' 'ANOXIC AND OTHER SEVERE BRAIN DAMAGE'
#  'EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'TRACHEOSTOMY WITH MV >96 HOURS WITHOUT EXTENSIVE PROCEDURE'
#  'CONCUSSION, CLOSED SKULL FRACTURE NOS, AND UNCOMPLICATED INTRACRANIAL INJURY, COMA < 1 HOUR OR NO COMA'
#  'PERITONEAL ADHESIOLYSIS' 'DENTAL DISEASES AND DISORDERS'
#  'FRACTURE OF PELVIS OR DISLOCATION OF HIP'
#  'MAJOR PANCREAS, LIVER AND SHUNT PROCEDURES'
#  'MAJOR HEMATOLOGIC OR IMMUNOLOGIC DIAGNOSES EXCEPT SICKLE CELL CRISIS AND COAGULATION'
#  'MAJOR BILIARY TRACT PROCEDURES'
#  'MALFUNCTION, REACTION, COMPLICATION OF ORTHOPEDIC DEVICE OR PROCEDURE'
#  'OTHER INJURY, POISONING AND TOXIC EFFECT DIAGNOSES'
#  'BURNS WITH SKIN GRAFT EXCEPT EXTENSIVE THIRD DEGREE BURNS'
#  'OTHER CARDIOTHORACIC AND THORACIC VASCULAR PROCEDURES'
#  'MALFUNCTION, REACTION, COMPLICATION OF CARDIAC OR VASCULAR DEVICE OR PROCEDURE'
#  'CARDIOMYOPATHY'
#  'MODERATELY EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'NEONATE BIRTH WEIGHT < 500 GRAMS, OR BIRTH WEIGHT 500-999 GRAMS AND GESTATIONAL AGE <24 WEEKS, OR BIRT'
#  'NONSPECIFIC CVA AND PRECEREBRAL OCCLUSION WITHOUT INFARCTION'
#  'EXTERNAL HEART ASSIST SYSTEMS' 'OTHER ENDOCRINE DISORDERS'
#  'DEFIBRILLATOR IMPLANTS'
#  'OTHER HEPATOBILIARY, PANCREAS AND ABDOMINAL PROCEDURES'
#  'ORGANIC MENTAL HEALTH DISTURBANCES'
#  'CORONARY BYPASS WITHOUT AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'MALIGNANCY OF HEPATOBILIARY SYSTEM AND PANCREAS'
#  'ORBIT AND EYE PROCEDURES'
#  'MAJOR GASTROINTESTINAL AND PERITONEAL INFECTIONS'
#  'HYPOVOLEMIA AND RELATED ELECTROLYTE DISORDERS'
#  'BREAST PROCEDURES EXCEPT MASTECTOMY'
#  'FEMALE REPRODUCTIVE SYSTEM MALIGNANCY'
#  'RENAL DIALYSIS ACCESS DEVICE PROCEDURES AND VESSEL REPAIR'
#  'NON-EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS'
#  'PERCUTANEOUS CARDIAC INTERVENTION WITH AMI'
#  'UTERINE AND ADNEXA PROCEDURES FOR NON-OVARIAN AND NON-ADNEXAL MALIGNANCY'
#  'SPINAL PROCEDURES' 'NEONATE, TRANSFERRED < 5 DAYS OLD, BORN HERE'
#  'INFLAMMATORY BOWEL DISEASE'
#  'THYROID, PARATHYROID AND THYROGLOSSAL PROCEDURES'
#  'MUSCULOSKELETAL MALIGNANCY AND PATHOLOGICAL FRACTURE DUE TO MUSCULOSKELETAL MALIGNANCY'
#  'OTHER STOMACH, ESOPHAGEAL AND DUODENAL PROCEDURES'
#  'BACTERIAL AND TUBERCULOUS INFECTIONS OF NERVOUS SYSTEM' 'ABDOMINAL PAIN'
#  'MUSCULOSKELETAL AND OTHER PROCEDURES FOR MULTIPLE SIGNIFICANT TRAUMA'
#  'OTHER PROCEDURES FOR ENDOCRINE, NUTRITIONAL AND METABOLIC DISORDERS'
#  'OPEN CRANIOTOMY FOR TRAUMA'
#  'NON-BACTERIAL INFECTIONS OF NERVOUS SYSTEM EXCEPT VIRAL MENINGITIS'
#  'HAND AND WRIST PROCEDURES' 'VIRAL ILLNESS'
#  'ACUTE AND SUBACUTE ENDOCARDITIS'
#  'HEMORRHAGE OR HEMATOMA DUE TO COMPLICATION'
#  'FEMALE REPRODUCTIVE SYSTEM RECONSTRUCTIVE PROCEDURES'
#  'KIDNEY AND URINARY TRACT MALIGNANCY'
#  'SHOULDER AND ELBOW JOINT REPLACEMENT'
#  'POSTPARTUM AND POST ABORTION DIAGNOSIS WITH O.R. PROCEDURE'
#  'PROCEDURE WITH DIAGNOSIS OF REHABILITATION, AFTERCARE OR OTHER CONTACT WITH HEALTH SERVICES'
#  'NON-ELECTIVE OR COMPLEX KNEE JOINT REPLACEMENT' 'EATING DISORDERS'
#  'FRACTURE OF FEMUR'
#  'PERMANENT CARDIAC PACEMAKER IMPLANT WITHOUT AMI, HEART FAILURE OR SHOCK'
#  'OTHER NERVOUS SYSTEM AND RELATED PROCEDURES'
#  'CORONARY BYPASS WITH AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'CARDIAC VALVE PROCEDURES WITHOUT AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'EAR, NOSE, MOUTH, THROAT AND CRANIAL OR FACIAL MALIGNANCIES'
#  'DILATION AND CURETTAGE FOR NON-OBSTETRIC DIAGNOSES'
#  'NERVOUS SYSTEM MALIGNANCY'
#  'SKIN GRAFT FOR SKIN AND SUBCUTANEOUS TISSUE DIAGNOSES'
#  'KIDNEY AND URINARY TRACT PROCEDURES FOR MALIGNANCY'
#  'UTERINE AND ADNEXA PROCEDURES FOR OVARIAN AND ADNEXAL MALIGNANCY'
#  'OTHER PERCUTANEOUS INTRACRANIAL PROCEDURES' 'GASTRIC FUNDOPLICATION'
#  'IMPLANTABLE HEART ASSIST SYSTEMS'
#  'NON-EXTENSIVE O.R. PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT'
#  'HEART AND/OR LUNG TRANSPLANT' 'THYROID DISORDERS'
#  'INBORN ERRORS OF METABOLISM' 'ANAL PROCEDURES' 'UNGROUPABLE'
#  'CARDIAC PACEMAKER AND DEFIBRILLATOR REVISION EXCEPT DEVICE REPLACEMENT'
#  'GASTROINTESTINAL VASCULAR INSUFFICIENCY' 'SPINAL DISORDERS AND INJURIES'
#  'MENTAL ILLNESS DIAGNOSIS WITH O.R. PROCEDURE'
#  'FEVER AND INFLAMMATORY CONDITIONS'
#  'INSERTION, REVISION AND REPLACEMENTS OF PACEMAKER AND OTHER CARDIAC DEVICES'
#  'MAJOR CRANIAL OR FACIAL BONE PROCEDURES'
#  'CYSTIC FIBROSIS - PULMONARY DISEASE'
#  'EXTENSIVE ABDOMINAL OR THORACIC PROCEDURES FOR MULTIPLE SIGNIFICANT TRAUMA'
#  'PRINCIPAL DIAGNOSIS INVALID AS DISCHARGE DIAGNOSIS'
#  'APPENDECTOMY WITH COMPLEX PRINCIPAL DIAGNOSIS'
#  'OTHER PROCEDURES OF BLOOD AND BLOOD-FORMING ORGANS'
#  'AUTOLOGOUS BONE MARROW TRANSPLANT OR T-CELL IMMUNOTHERAPY'
#  'OTHER KIDNEY, URINARY TRACT AND RELATED PROCEDURES'
#  'SKIN GRAFT, EXCEPT HAND, FOR MUSCULOSKELETAL AND CONNECTIVE TISSUE DIAGNOSES'
#  'OTHER O.R. PROCEDURES FOR LYMPHATIC, HEMATOPOIETIC OR OTHER NEOPLASMS'
#  'BRAIN CONTUSION OR LACERATION AND COMPLICATED SKULL FRACTURE, COMA < 1 HOUR OR NO COMA'
#  'PARTIAL THICKNESS BURNS WITHOUT SKIN GRAFT' 'VIRAL MENINGITIS'
#  'NEONATE BIRTH WEIGHT 1500-2499 GRAMS WITH MAJOR PROCEDURE'
#  'LIVER TRANSPLANT AND/OR INTESTINAL TRANSPLANT'
#  'CRANIOTOMY FOR MULTIPLE SIGNIFICANT TRAUMA' 'OTHER OPEN CRANIOTOMY'
#  'CARDIAC VALVE PROCEDURES WITH AMI OR COMPLEX PRINCIPAL DIAGNOSIS'
#  'PERMANENT CARDIAC PACEMAKER IMPLANT WITH AMI, HEART FAILURE OR SHOCK'
#  'ADRENAL PROCEDURES' 'RADIOTHERAPY'
#  'EXTENSIVE THIRD DEGREE BURNS WITHOUT SKIN GRAFT'
#  'MAJOR CARDIOTHORACIC REPAIR OF HEART ANOMALY'
#  'OTHER MAJOR HEAD AND NECK PROCEDURES'
#  'ALLOGENEIC BONE MARROW TRANSPLANT'
#  'PELVIC EVISCERATION, RADICAL HYSTERECTOMY AND OTHER RADICAL GYNECOLOGICAL PROCEDURES'
#  'NEONATE BIRTH WEIGHT 1250-1499 GRAMS WITH OR WITHOUT SIGNIFICANT CONDITION'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH OTHER MAJOR PROCEDURE'
#  'NEONATE BIRTH WEIGHT > 2499 GRAMS WITH MAJOR CARDIOVASCULAR PROCEDURE'
#  'PANCREAS TRANSPLANT' 'NEONATAL AFTERCARE'
#  'EXTRACORPOREAL MEMBRANE OXYGENATION (ECMO)' 'NEONATE WITH ECMO'
#  'NEONATE, TRANSFERRED < 5 DAYS OLD, NOT BORN HERE' 'SPLENECTOMY'
#  'EXTENSIVE THIRD DEGREE BURNS WITH SKIN GRAFT'
#  'NEONATE BIRTH WEIGHT < 1500 GRAMS WITH MAJOR PROCEDURE'
#  'NEONATE BIRTH WEIGHT 1000-1249 GRAMS WITH OR WITHOUT SIGNIFICANT CONDITION'
#  'NEONATE BIRTH WEIGHT 1500-1999 GRAMS WITH CONGENITAL OR PERINATAL INFECTION']
# apr_severity_of_illness_description : ['Major' 'Moderate' 'Minor' 'Extreme' nan]
# apr_risk_of_mortality : ['Extreme' 'Minor' 'Major' 'Moderate' nan]
# apr_medical_surgical_description : ['Medical' 'Surgical' 'Not Applicable']
# emergency_department_indicator : ['Y' 'N']
# apr_mdc_description : ['DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM'
#  'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM'
#  'PREGNANCY, CHILDBIRTH AND THE PUERPERIUM'
#  'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT'
#  'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS'
#  'NEWBORNS AND OTHER NEONATES WITH CONDITIONS ORIGINATING IN THE PERINATAL PERIOD'
#  'INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)'
#  'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM'
#  'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS'
#  'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS'
#  'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE'
#  'MYELOPROLIFERATIVE DISEASES AND DISORDERS, AND POORLY DIFFERENTIATED NEOPLASM'
#  'DISEASES AND DISORDERS OF THE MALE REPRODUCTIVE SYSTEM'
#  'MENTAL DISEASES AND DISORDERS'
#  'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM'
#  'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS'
#  'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS'
#  'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES'
#  'DISEASES AND DISORDERS OF THE HEPATOBILIARY SYSTEM AND PANCREAS'
#  'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST'
#  'MULTIPLE SIGNIFICANT TRAUMA'
#  'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM'
#  'DISEASES AND DISORDERS OF THE EYE'
#  'DISEASES AND DISORDERS OF THE EAR, NOSE, MOUTH AND THROAT' 'BURNS'
#  'PRE MDC']
# Unique value counts per column:
# length_of_stay                         119
# age_group                                5
# gender                                   3
# type_of_admission                        6
# ccsr_diagnosis_description             477
# ccsr_procedure_description             320
# apr_drg_description                    334
# apr_severity_of_illness_description      4
# apr_risk_of_mortality                    4
# apr_medical_surgical_description         3
# emergency_department_indicator           2
# apr_mdc_description                     26
# dtype: int64

# %% [markdown]
# ## Drop Rows with Null Values

# %%
# Compute how many rows remain if we drop any entry with a null in any column
rows_before = len(df)
rows_after = df.dropna().shape[0]
print(f"\nRows before dropping nulls: {rows_before}")
print(f"Rows after dropping any nulls: {rows_after}")

df = df.dropna()
# Out:
# Rows before dropping nulls: 2100027
# Rows after dropping any nulls: 1522692

# %% [markdown]
# ## Save Cleaned Data as New CSV

# %%
# Create new csv
df.to_csv("hospital_cleaned.csv", index=False)

# %%
# Added later in project process: create dataset with same cleaning steps applied, but only with columns 
# with a length of stay of 21 days or less, since 21-28 days and 28+ days only makes up around 5% of the dataset
# so there is an uneven distribution of data that was affecting the models accuracy
df.drop(df[df['length_of_stay'] > 21].index, inplace=True)
df.to_csv("hospital_los_21.csv",index=False)
